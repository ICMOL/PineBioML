# %%
import pandas as pd
import numpy as np
import os

# %%
import package
from package.preprocessing import IO

# %%
os.listdir(".")
# Out:
# ['.git',
#  'ablation.ipynb',
#  'documents',
#  'example_feature_selection.ipynb',
#  'images',
#  'input',
#  'LICENSE',
#  'log.txt',
#  'output',
#  'package',
#  'Pipfile',
#  'Pipfile.lock',
#  'README.md',
#  'requirements.txt']

# %% [markdown]
# # IO

# %%
input_path = "./input/proteomics.csv"
export_title = "PDA "

# %%
proteomics = IO.read_file(input_path).set_index("patientID-radiomics", drop = True).drop("Withdrawn", axis =1)
proteomics.head(5)
# Out:
#                               Tumor/Normal        A1BG       A1CF        A2M  \
# patientID-radiomics
# C3N-03884                             Tumor  28.424135  24.246165  29.366812
# C3L-00589            Normal Adjacent Tissue  28.502926  25.717743  29.883149
# C3L-03123            Normal Adjacent Tissue  28.297751  24.580732  29.130757
# C3L-01687            Normal Adjacent Tissue  28.662810  25.795589  29.768221
# C3L-03123                             Tumor  28.481919  23.815981  29.085915
#
#                      A2ML1  A4GALT  A4GNT       AAAS       AACS      AADAC  \
# patientID-radiomics
# C3N-03884              NaN     NaN    NaN  22.839828  24.662698  23.246860
# C3L-00589              NaN     NaN    NaN  23.046828  25.270276  25.790888
# C3L-03123              NaN     NaN    NaN  22.625520  24.676915  23.268602
# C3L-01687              NaN     NaN    NaN  23.093415  24.957128  24.926253
# C3L-03123              NaN     NaN    NaN  23.336621  24.811962  22.560420
#
#                      ...  ZSWIM9       ZW10     ZWILCH  ZWINT  ZXDA  \
# patientID-radiomics  ...
# C3N-03884            ...     NaN  25.017461  24.306182    NaN   NaN
# C3L-00589            ...     NaN  25.295479  24.091819    NaN   NaN
# C3L-03123            ...     NaN  25.186219  23.137290    NaN   NaN
# C3L-01687            ...     NaN  25.188314  24.046851    NaN   NaN
# C3L-03123            ...     NaN  25.037140  23.892358    NaN   NaN
#
#                           ZXDC     ZYG11B        ZYX      ZZEF1  ZZZ3
# patientID-radiomics
# C3N-03884            18.946509  21.198617  28.930222  25.255542   NaN
# C3L-00589            18.750975  20.866134  28.242476  26.168199   NaN
# C3L-03123            18.304164  21.223762  28.269888  25.257447   NaN
# C3L-01687            18.644933  21.022914  28.310557  25.858360   NaN
# C3L-03123            18.513350  21.160126  28.869091  25.144300   NaN
#
# [5 rows x 12589 columns]

# %%
x = np.power(2, proteomics.drop("Tumor/Normal ", axis = 1))
y = proteomics["Tumor/Normal "] == "Tumor"

# %%
x.head(5)
# Out:
#                              A1BG          A1CF           A2M  A2ML1  A4GALT  \
# patientID-radiomics
# C3N-03884            3.601780e+08  1.989862e+07  6.922953e+08    NaN     NaN
# C3L-00589            3.803959e+08  5.518385e+07  9.902032e+08    NaN     NaN
# C3L-03123            3.299680e+08  2.509213e+07  5.878028e+08    NaN     NaN
# C3L-01687            4.249772e+08  5.824332e+07  9.143817e+08    NaN     NaN
# C3L-03123            3.748969e+08  1.476810e+07  5.698136e+08    NaN     NaN
#
#                      A4GNT          AAAS          AACS         AADAC  AADAT  \
# patientID-radiomics
# C3N-03884              NaN  7.507121e+06  2.655900e+07  9.954105e+06    NaN
# C3L-00589              NaN  8.665357e+06  4.046794e+07  5.805382e+07    NaN
# C3L-03123              NaN  6.470833e+06  2.682203e+07  1.010525e+07    NaN
# C3L-01687              NaN  8.949746e+06  3.257198e+07  3.188232e+07    NaN
# C3L-03123              NaN  1.059310e+07  2.945404e+07  6.185335e+06    NaN
#
#                      ...  ZSWIM9          ZW10        ZWILCH  ZWINT  ZXDA  \
# patientID-radiomics  ...
# C3N-03884            ...     NaN  3.396301e+07  2.074387e+07    NaN   NaN
# C3L-00589            ...     NaN  4.118111e+07  1.787970e+07    NaN   NaN
# C3L-03123            ...     NaN  3.817749e+07  9.226104e+06    NaN   NaN
# C3L-01687            ...     NaN  3.823298e+07  1.733100e+07    NaN   NaN
# C3L-03123            ...     NaN  3.442946e+07  1.557100e+07    NaN   NaN
#
#                               ZXDC        ZYG11B           ZYX         ZZEF1  \
# patientID-radiomics
# C3N-03884            505204.942515  2.406687e+06  5.115225e+08  4.005674e+07
# C3L-00589            441169.965734  1.911315e+06  3.175649e+08  7.540723e+07
# C3L-03123            323669.898241  2.449001e+06  3.236565e+08  4.010968e+07
# C3L-01687            409905.799064  2.130726e+06  3.329101e+08  6.083339e+07
# C3L-03123            374174.127860  2.343325e+06  4.903005e+08  3.708417e+07
#
#                      ZZZ3
# patientID-radiomics
# C3N-03884             NaN
# C3L-00589             NaN
# C3L-03123             NaN
# C3L-01687             NaN
# C3L-03123             NaN
#
# [5 rows x 12588 columns]

# %%
y.head(5)
# Out:
# patientID-radiomics
# C3N-03884     True
# C3L-00589    False
# C3L-03123    False
# C3L-01687    False
# C3L-03123     True
# Name: Tumor/Normal , dtype: bool

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### Impute

# %%
from package.preprocessing import impute, bagging

# %% [raw]
# knn_imputer(
#     threshold : float from (0, 1]   # if feature missing rate > threshold, then
#                                     # drop the feature.
#     n_neighbor : int > 0            # number of neighbor for imputing.
# )
#
# simple_imputer(
#     threshold : float from (0, 1]   # if feature missing rate > threshold, then
#                                     # drop the feature.
#     strategy : ["median", "mean"]   # method to impute the feature.
# )

# %%
simple = impute.simple_imputer(threshold = 0.3333, strategy = "median")
simple.fit_transform(x, y)

knn = impute.knn_imputer(threshold = 0.3333, n_neighbor = 5)
x, y = knn.fit_transform(x, y)

# %%
x.head(5)
# Out:
#                              A1BG          A1CF           A2M         A2ML1  \
# patientID-radiomics
# C3N-03884            3.601780e+08  1.989862e+07  6.922953e+08  1.001351e+07
# C3L-00589            3.803959e+08  5.518385e+07  9.902032e+08  2.428902e+06
# C3L-03123            3.299680e+08  2.509213e+07  5.878028e+08  3.556857e+06
# C3L-01687            4.249772e+08  5.824332e+07  9.143817e+08  2.428902e+06
# C3L-03123            3.748969e+08  1.476810e+07  5.698136e+08  5.521517e+06
#
#                              AAAS          AACS         AADAC         AAGAB  \
# patientID-radiomics
# C3N-03884            7.507121e+06  2.655900e+07  9.954105e+06  1.700950e+07
# C3L-00589            8.665357e+06  4.046794e+07  5.805382e+07  1.643521e+07
# C3L-03123            6.470833e+06  2.682203e+07  1.010525e+07  1.625682e+07
# C3L-01687            8.949746e+06  3.257198e+07  3.188232e+07  1.644599e+07
# C3L-03123            1.059310e+07  2.945404e+07  6.185335e+06  1.853726e+07
#
#                              AAK1         AAMDC  ...          ZPR1  \
# patientID-radiomics                              ...
# C3N-03884            3.930431e+07  5.692694e+07  ...  3.962214e+07
# C3L-00589            3.500768e+07  8.411769e+07  ...  3.034699e+07
# C3L-03123            3.763716e+07  8.809936e+07  ...  3.010763e+07
# C3L-01687            3.502954e+07  7.932558e+07  ...  3.443084e+07
# C3L-03123            4.363844e+07  5.637029e+07  ...  4.181187e+07
#
#                            ZRANB2       ZSCAN18        ZSWIM8          ZW10  \
# patientID-radiomics
# C3N-03884            1.290026e+08  6.101920e+06  6.596625e+06  3.396301e+07
# C3L-00589            1.077997e+08  5.956067e+06  6.544889e+06  4.118111e+07
# C3L-03123            1.482483e+08  5.617840e+06  6.430990e+06  3.817749e+07
# C3L-01687            1.074707e+08  9.190937e+06  6.714496e+06  3.823298e+07
# C3L-03123            1.342225e+08  6.403648e+06  6.687848e+06  3.442946e+07
#
#                            ZWILCH        ZYG11B           ZYX         ZZEF1  \
# patientID-radiomics
# C3N-03884            2.074387e+07  2.406687e+06  5.115225e+08  4.005674e+07
# C3L-00589            1.787970e+07  1.911315e+06  3.175649e+08  7.540723e+07
# C3L-03123            9.226104e+06  2.449001e+06  3.236565e+08  4.010968e+07
# C3L-01687            1.733100e+07  2.130726e+06  3.329101e+08  6.083339e+07
# C3L-03123            1.557100e+07  2.343325e+06  4.903005e+08  3.708417e+07
#
#                              ZZZ3
# patientID-radiomics
# C3N-03884            1.358649e+06
# C3L-00589            1.027846e+06
# C3L-03123            1.449336e+06
# C3L-01687            1.027846e+06
# C3L-03123            1.299666e+06
#
# [5 rows x 9106 columns]

# %% [markdown]
# ### Bagging

# %% [markdown]
# bagger = bagging.bagger()
# x, y = bagger.fit_transform(x, y)

# %% [markdown]
# print(bagger.see("AAMP")) # AAMP is a feature
# print(bagger.see("AA"))   # no AA but some other feature start with AA
# print(bagger.see("AA*"))  # * can list all features start with ZN
# try:
#     print(bagger.see("ERROR"))
# except:
#     print("ERROR is not a feature in x, it will raise an error")

# %% [markdown]
# # Feature selection

# %%
from package.selection.ensemble import selector

# %%
important_feature, importance = selector().select(x, y, 20)
# Out:
# Using  id3  to select.
# 100%|██████████| 9106/9106 [00:18<00:00, 496.42it/s]
# id3  is done.
#
# Using  c45  to select.
# 100%|██████████| 9106/9106 [00:28<00:00, 324.46it/s]
# c45  is done.
#
# Using  RF_gini  to select.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 784 tasks      | elapsed:    3.4s
# [Parallel(n_jobs=-1)]: Done 1234 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=-1)]: Done 1784 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=-1)]: Done 2434 tasks      | elapsed:   10.4s
# [Parallel(n_jobs=-1)]: Done 3184 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done 4034 tasks      | elapsed:   17.7s
# [Parallel(n_jobs=-1)]: Done 4984 tasks      | elapsed:   22.1s
# [Parallel(n_jobs=-1)]: Done 6034 tasks      | elapsed:   27.2s
# [Parallel(n_jobs=-1)]: Done 7184 tasks      | elapsed:   33.8s
# [Parallel(n_jobs=-1)]: Done 8434 tasks      | elapsed:   40.6s
# [Parallel(n_jobs=-1)]: Done 9784 tasks      | elapsed:   47.6s
# [Parallel(n_jobs=-1)]: Done 11234 tasks      | elapsed:   54.9s
# [Parallel(n_jobs=-1)]: Done 12784 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=-1)]: Done 14434 tasks      | elapsed:  1.2min
# [Parallel(n_jobs=-1)]: Done 16184 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 16384 out of 16384 | elapsed:  1.4min finished
# RF_gini  is done.
#
# Using  RF_etropy  to select.
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 434 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 784 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 1234 tasks      | elapsed:    7.4s
# [Parallel(n_jobs=-1)]: Done 1784 tasks      | elapsed:   10.3s
# [Parallel(n_jobs=-1)]: Done 2434 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 3184 tasks      | elapsed:   18.3s
# [Parallel(n_jobs=-1)]: Done 4034 tasks      | elapsed:   22.8s
# [Parallel(n_jobs=-1)]: Done 4984 tasks      | elapsed:   28.1s
# [Parallel(n_jobs=-1)]: Done 6034 tasks      | elapsed:   33.5s
# [Parallel(n_jobs=-1)]: Done 7184 tasks      | elapsed:   39.2s
# [Parallel(n_jobs=-1)]: Done 8434 tasks      | elapsed:   45.4s
# [Parallel(n_jobs=-1)]: Done 9784 tasks      | elapsed:   52.1s
# [Parallel(n_jobs=-1)]: Done 11234 tasks      | elapsed:   59.3s
# [Parallel(n_jobs=-1)]: Done 12784 tasks      | elapsed:  1.1min
# [Parallel(n_jobs=-1)]: Done 14434 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 16184 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=-1)]: Done 16384 out of 16384 | elapsed:  1.4min finished
# RF_etropy  is done.
#
# Using  AdaBoost  to select.
# I don't have a progress bar but I am running
# AdaBoost  is done.
#
# Using  Lasso  to select.
#   4%|▍         | 40/999 [00:10<04:09,  3.84it/s]
# all coefficient are dead, terminated.
# Lasso  is done.
#
# Using  multi_Lasso  to select.
# C:\Users\aimhi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.030e-02, tolerance: 5.950e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aimhi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.048e-02, tolerance: 5.950e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aimhi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.304e-02, tolerance: 5.950e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\aimhi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.304e-02, tolerance: 5.950e-03
#   model = cd_fast.enet_coordinate_descent(
# multi_Lasso  is done.
#
# Using  SVM  to select.
# SVM  is done.
#
# Using  multi_SVM  to select.
# multi_SVM  is done.
#
# Using  Volcano_p  to select.
# Volcano_p  is done.
#
# Using  Volcano_fold  to select.
# Volcano_fold  is done.
#
# Using  XGboost  to select.
# C:\Users\aimhi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\xgboost\data.py:335: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(dtype):
# C:\Users\aimhi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\xgboost\data.py:338: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   is_categorical_dtype(dtype) or is_pa_ext_categorical_dtype(dtype)
# C:\Users\aimhi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\xgboost\data.py:384: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if is_categorical_dtype(dtype):
# C:\Users\aimhi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\xgboost\data.py:359: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   return is_int or is_bool or is_float or is_categorical_dtype(dtype)
# C:\Users\aimhi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\xgboost\data.py:520: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(data):
# XGboost  is done.
#
# Using  Lightgbm  to select.
# [LightGBM] [Info] Number of positive: 145, number of negative: 93
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.102301 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 737319
# [LightGBM] [Info] Number of data points in the train set: 238, number of used features: 9106
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.500000 -> initscore=0.000000
# [LightGBM] [Info] Start training from score 0.000000
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Lightgbm  is done.

# %% [markdown]
# # Output

# %% [markdown]
# # unbagging
# important_feature = important_feature.map(bagger.unbagging)

# %%
important_feature.to_csv("./output/"+export_title+ " important feature.csv")

# %%
important_feature
# Out:
#    DT_score_id3 DT_score_c45 RandomForest_gini RandomForest_entropy  \
# 0          MSLN        TRAM1             INHBA                PDZK1
# 1        PM20D1         MSLN            MICAL2                 FHL2
# 2         LAMC2        MXRA5              CNN2                MMP14
# 3           FN1       ANTXR1            ARPC1B               MICAL2
# 4        IGFBP3      PLA2G1B             MMP14                P4HA1
# 5         FNDC1        LAMC2              PLEC                MXRA5
# 6       COL11A1       IGFBP3          LGALS3BP                 PLEC
# 7         TRAM1      COL11A1             SAMD9                INHBA
# 8         LAMA3          FN1               HK2               ARPC1B
# 9         LAMB3       S100A6             P4HA1                LAMC2
# 10        THBS2        LAMA3              FHL2                  HK2
# 11        PRSS1        LAMB3           COL12A1                PLOD3
# 12       ZNF185        FNDC1             LAMC2                MYO1E
# 13     LGALS3BP        THBS2             MXRA5              COL12A1
# 14        AEBP1        KRT16             STAT2               OSBPL3
# 15        LOXL2        LOXL2             THBS2                SAMD9
# 16        KRT16       ZNF185            OSBPL3                STAT2
# 17         FGL1        AEBP1            PGM2L1                THBS2
# 18      PLA2G1B     LGALS3BP             MYO1E               PGM2L1
# 19      COL12A1      COL12A1             SULF1                SULF1
#
#    AdaBoost64 LassoLinear multi_Lasso        SVM  multi_svm Volcano Plot_p  \
# 0      BRMS1L        SIAE        MYOF     PAPSS2    MRPS18B          HTRA3
# 1     PRKAR2A       FMNL3       AP2A1     CXCL17        PGC         ITGBL1
# 2       MOCS2         GLA         GLS      REG3G     PAPSS2         S100A6
# 3       STAT2       PDZK1     SPATS2L      GFOD2      CYTH3          INHBA
# 4       RBMS2        PNPO       CYB5A        PGC     CXCL17            HK2
# 5        FHL2       LTBP1     ALDH1A1      CYTH3     TUBB4A          SULF2
# 6       DTX3L       GSTM2       HMGN5       CD36       CD36       LGALS3BP
# 7        TPPP     ALDH1A1       PDZK1     TUBB4A      GFOD2         COL3A1
# 8     TXNDC11     SPATS2L       ETFDH     PDE11A     PDE11A          FBLN2
# 9       LAMC2       NCAM1        WNK2        RLF        RLF         COL8A1
# 10       PLEC        PFAS        MYH9  IGHV1-69D  IGHV1-69D          MXRA5
# 11     MICAL2        IMUP       SULF1     DENND3     CELSR1           NNMT
# 12     PGM2L1      OSBPL3        DAG1     CELSR1      NCAM1            FAP
# 13      ITGAV      MICAL2       AFAP1      NCAM1     DENND3          KRT19
# 14      RABL6       HMGN5         PML      LAMA1      LAMA1          LTBP1
# 15   SERPINB5       PARP9        A1CF       PNPO       PNPO           CNN2
# 16        HBB       SULF1       STAT2     SPINK4     SPINK4       ADAMTS12
# 17       IMUP      ARPC1B       RAI14       TFF3       TFF3           FHL2
# 18    SDR16C5       STAT2      ARPC1B       REG4       REG4        S100A11
# 19      SULF1       MYO1E       MYO1E      MON1A      MON1A          SULF1
#
#    Volcano Plot_fold  XGboost  Lightgbm
# 0              DHRS2    NCAM1       HK1
# 1               CPA1   PGM2L1     STAT2
# 2               CLPS    ITGAV     NCAM1
# 3             PAIP2B     SCEL      CD55
# 4            SLC43A1     ABAT     MRPS6
# 5              NUPR1  PRKAR2A    MRPS28
# 6              AMY2A      FAP  ADAMTS12
# 7                CEL     PNPO     RBMS2
# 8               CPA2    LAMC2      AASS
# 9              AMY2B    ACBD5     MXRA5
# 10             PRSS1      SFN     CYB5A
# 11             PNLIP      NPY   PRKAR2A
# 12          PNLIPRP2    ADH1A  PPP1R12A
# 13            AQP12B   MICAL2      TPPP
# 14              KLK1     NUMB      FAT1
# 15             PRSS3      HK2    NDUFV2
# 16          SERPINI2    HMGN5     LAMC2
# 17              SYCN    MYO1E     ITGAV
# 18              AQP8    SAMD9    PGM2L1
# 19           PLA2G1B    SULF1     SULF1

# %%
importance.to_csv("./output/"+export_title+ " importance.csv")
