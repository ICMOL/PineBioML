# %% [markdown]
# # IO

# %%
from PineBioML import IO

# %%
# Path
input_folder = "./input/"
output_folder = "./output/"
export_title = "example_basic "

# %%
##### Read data method 1: read single file
##### index_col is the column of index of samples (or sample name).
##### If your data do not have such column, please set index_col=None
data = IO.read_file(input_folder+ "HAPTdata.csv", index_col=None)

##### pick the target label column
y = data["target"]

##### drop the target from dataframe, using the remaining to predict y (the target)
x = data.drop("target", axis = 1)

# %%
x.head(5)
# Out:
#     Column1   Column2   Column3   Column4   Column5   Column6   Column7  \
# 0  0.030914 -0.008927  0.040382 -0.938504 -0.944626 -0.759334 -0.952398
# 1  0.042548  0.001079 -0.026236 -0.975516 -0.977502 -0.960146 -0.986694
# 2  0.038297 -0.011660 -0.025643 -0.993922 -0.979215 -0.973030 -0.994298
# 3  0.036205 -0.018148 -0.025240 -0.994845 -0.981534 -0.976175 -0.995169
# 4  0.038034 -0.013437 -0.032899 -0.993955 -0.977493 -0.984290 -0.994006
#
#     Column8   Column9  Column10  ...  Column552  Column553  Column554  \
# 0 -0.950281 -0.802483 -0.757099  ...   0.122830  -0.345684  -0.709087
# 1 -0.978983 -0.966820 -0.757099  ...  -0.314688  -0.142804  -0.600867
# 2 -0.980535 -0.977508 -0.799005  ...   0.114730  -0.209525  -0.645500
# 3 -0.983020 -0.980785 -0.798401  ...   0.164515  -0.359352  -0.738474
# 4 -0.977354 -0.985899 -0.798401  ...  -0.056085  -0.544467  -0.846150
#
#    Column555  Column556  Column557  Column558  Column559  Column560  Column561
# 0   0.006462   0.162920  -0.825886   0.271151  -0.720559   0.276779  -0.051074
# 1  -0.083495   0.017500  -0.434375   0.920593  -0.698684   0.281322  -0.076825
# 2  -0.034956   0.202302   0.064103   0.145068  -0.703355   0.280062  -0.072302
# 3  -0.017067   0.154438   0.340134   0.296407  -0.699545   0.284093  -0.070079
# 4  -0.002223  -0.040046   0.736715  -0.118545  -0.692849   0.290701  -0.066849
#
# [5 rows x 561 columns]

# %%
y.value_counts()
# Out:
# target
# STANDING              556
# LAYING                545
# SITTING               508
# WALKING               496
# WALKING_UPSTAIRS      471
# WALKING_DOWNSTAIRS    420
# STAND_TO_LIE           49
# SIT_TO_LIE             32
# LIE_TO_STAND           27
# LIE_TO_SIT             25
# STAND_TO_SIT           23
# SIT_TO_STAND           10
# Name: count, dtype: int64

# %% [markdown]
# # Preprocessing

# %%
from PineBioML.preprocessing import Normalizer

x = Normalizer(method="StandardScaler").fit_transform(x)

# %%
# Impute 0
from PineBioML.preprocessing import impute

# The imputer will drop the features with missing value more than 60%.
# Remaining will be filled by 0.
simple = impute.simple_imputer(threshold = 0.6, strategy = "constant")
x = simple.fit_transform(x)

# %% [markdown]
# # Data overview

# %%
import PineBioML.report.utils as report_utils

# %%
report_utils.data_overview(x, y, is_classification=True, prefix="Original Data ", save_fig=True, save_path="./output/images/", show_fig=True)

# %% [markdown]
# # Feature selection

# %%
from PineBioML.selection.classification import essemble_selector

# %%
# Use several way to select top-k important features, which includes decision tree, random forest, lasso, multi lasso, svm, adaboost, xgboost
ensemble_selector = essemble_selector(k = 10, z_importance_threshold=None)
important_feature, importance = ensemble_selector.Select(x, y) # if k = -1, it returns all the feature scores
# Out:
# Using  c45  to select.
# 100%|██████████| 561/561 [00:04<00:00, 132.19it/s]
# c45  is done.
#
# Using  RF_gini  to select.
# RF_gini  is done.
#
# Using  Lasso_Bisection  to select.
# Lasso_Bisection  is done.
#
# Using  multi_Lasso  to select.
# multi_Lasso  is done.
#
# Using  SVM  to select.
# SVM  is done.
#
# Using  AdaBoost  to select.
# I don't have a progress bar but I am running
# AdaBoost  is done.
#
# Using  XGboost  to select.
# XGboost  is done.
#
# Using  Lightgbm  to select.
# Lightgbm  is done.

# %%
# The features that was selected by ML algoritms.
important_feature
# Out:
#   DT_score_c45 RandomForest_gini LassoLinear multi_Lasso        SVM  \
# 0     Column69          Column53     Column1    Column47  Column446
# 1     Column68           Column1    Column61    Column60  Column183
# 2     Column26          Column23    Column44     Column1  Column143
# 3    Column144          Column41    Column50    Column44  Column559
# 4    Column294          Column57     Column2   Column497  Column146
# 5     Column70          Column54    Column64    Column45    Column2
# 6    Column106         Column559     Column3     Column3  Column557
# 7    Column374          Column50    Column19   Column489   Column50
# 8    Column145          Column51   Column489   Column317   Column25
# 9     Column25         Column382    Column46    Column48   Column13
#
#   AdaBoost128    XGboost   Lightgbm
# 0    Column16  Column337   Column50
# 1   Column382  Column126    Column1
# 2     Column1  Column469  Column103
# 3         NaN  Column538    Column2
# 4         NaN  Column382  Column382
# 5         NaN  Column543   Column42
# 6         NaN  Column513  Column295
# 7         NaN  Column560  Column130
# 8         NaN  Column465  Column452
# 9         NaN   Column82   Column41

# %%
# The feature importance given by diffirent methods.
# Please Notice that the score between diffirent methods is not comparable.
importance
# Out:
#            DT_score_c45  RandomForest_gini  LassoLinear  multi_Lasso  \
# Column69       0.702054                NaN          NaN          NaN
# Column68       0.701797                NaN          NaN          NaN
# Column26       0.701755                NaN          NaN          NaN
# Column144      0.701752                NaN          NaN          NaN
# Column294      0.701679                NaN          NaN          NaN
# Column70       0.701296                NaN          NaN          NaN
# Column106      0.701276                NaN          NaN          NaN
# Column374      0.701244                NaN          NaN          NaN
# Column145      0.701222                NaN          NaN          NaN
# Column25       0.701212                NaN          NaN          NaN
# Column53            NaN           0.019357          NaN          NaN
# Column1             NaN           0.015620     0.039428     0.022493
# Column23            NaN           0.015236          NaN          NaN
# Column41            NaN           0.015177          NaN          NaN
# Column57            NaN           0.014862          NaN          NaN
# Column54            NaN           0.013785          NaN          NaN
# Column559           NaN           0.013179          NaN          NaN
# Column50            NaN           0.013134     0.021531          NaN
# Column51            NaN           0.012441          NaN          NaN
# Column382           NaN           0.012360          NaN          NaN
# Column61            NaN                NaN     0.023152          NaN
# Column44            NaN                NaN     0.022015     0.019071
# Column2             NaN                NaN     0.018787          NaN
# Column64            NaN                NaN     0.011399          NaN
# Column3             NaN                NaN     0.008390     0.006653
# Column19            NaN                NaN     0.006474          NaN
# Column489           NaN                NaN     0.003329     0.006278
# Column46            NaN                NaN     0.000440          NaN
# Column47            NaN                NaN          NaN     0.030436
# Column60            NaN                NaN          NaN     0.024854
# Column497           NaN                NaN          NaN     0.009473
# Column45            NaN                NaN          NaN     0.007871
# Column317           NaN                NaN          NaN     0.005736
# Column48            NaN                NaN          NaN     0.005348
# Column446           NaN                NaN          NaN          NaN
# Column183           NaN                NaN          NaN          NaN
# Column143           NaN                NaN          NaN          NaN
# Column146           NaN                NaN          NaN          NaN
# Column557           NaN                NaN          NaN          NaN
# Column13            NaN                NaN          NaN          NaN
# Column16            NaN                NaN          NaN          NaN
# Column337           NaN                NaN          NaN          NaN
# Column126           NaN                NaN          NaN          NaN
# Column469           NaN                NaN          NaN          NaN
# Column538           NaN                NaN          NaN          NaN
# Column543           NaN                NaN          NaN          NaN
# Column513           NaN                NaN          NaN          NaN
# Column560           NaN                NaN          NaN          NaN
# Column465           NaN                NaN          NaN          NaN
# Column82            NaN                NaN          NaN          NaN
# Column103           NaN                NaN          NaN          NaN
# Column42            NaN                NaN          NaN          NaN
# Column295           NaN                NaN          NaN          NaN
# Column130           NaN                NaN          NaN          NaN
# Column452           NaN                NaN          NaN          NaN
#
#                 SVM  AdaBoost128   XGboost  Lightgbm
# Column69        NaN          NaN       NaN       NaN
# Column68        NaN          NaN       NaN       NaN
# Column26        NaN          NaN       NaN       NaN
# Column144       NaN          NaN       NaN       NaN
# Column294       NaN          NaN       NaN       NaN
# Column70        NaN          NaN       NaN       NaN
# Column106       NaN          NaN       NaN       NaN
# Column374       NaN          NaN       NaN       NaN
# Column145       NaN          NaN       NaN       NaN
# Column25   0.004619          NaN       NaN       NaN
# Column53        NaN          NaN       NaN       NaN
# Column1         NaN     0.111156       NaN     596.0
# Column23        NaN          NaN       NaN       NaN
# Column41        NaN          NaN       NaN     339.0
# Column57        NaN          NaN       NaN       NaN
# Column54        NaN          NaN       NaN       NaN
# Column559  0.006027          NaN       NaN       NaN
# Column50   0.004620          NaN       NaN     647.0
# Column51        NaN          NaN       NaN       NaN
# Column382       NaN     0.226070  0.026900     435.0
# Column61        NaN          NaN       NaN       NaN
# Column44        NaN          NaN       NaN       NaN
# Column2    0.005070          NaN       NaN     452.0
# Column64        NaN          NaN       NaN       NaN
# Column3         NaN          NaN       NaN       NaN
# Column19        NaN          NaN       NaN       NaN
# Column489       NaN          NaN       NaN       NaN
# Column46        NaN          NaN       NaN       NaN
# Column47        NaN          NaN       NaN       NaN
# Column60        NaN          NaN       NaN       NaN
# Column497       NaN          NaN       NaN       NaN
# Column45        NaN          NaN       NaN       NaN
# Column317       NaN          NaN       NaN       NaN
# Column48        NaN          NaN       NaN       NaN
# Column446  0.010761          NaN       NaN       NaN
# Column183  0.010248          NaN       NaN       NaN
# Column143  0.007410          NaN       NaN       NaN
# Column146  0.005457          NaN       NaN       NaN
# Column557  0.004908          NaN       NaN       NaN
# Column13   0.004532          NaN       NaN       NaN
# Column16        NaN     0.662774       NaN       NaN
# Column337       NaN          NaN  0.056743       NaN
# Column126       NaN          NaN  0.043730       NaN
# Column469       NaN          NaN  0.035653       NaN
# Column538       NaN          NaN  0.027915       NaN
# Column543       NaN          NaN  0.024221       NaN
# Column513       NaN          NaN  0.021585       NaN
# Column560       NaN          NaN  0.020939       NaN
# Column465       NaN          NaN  0.020143       NaN
# Column82        NaN          NaN  0.018277       NaN
# Column103       NaN          NaN       NaN     514.0
# Column42        NaN          NaN       NaN     354.0
# Column295       NaN          NaN       NaN     351.0
# Column130       NaN          NaN       NaN     343.0
# Column452       NaN          NaN       NaN     340.0

# %%
x = ensemble_selector.transform(x)

# %%
# Overviewing the top-5 features.
report_utils.data_overview(x, y, is_classification=True, prefix="Seleted Data ", save_fig=True, save_path="./output/images/", show_fig=True)

# %% [markdown]
# # Modeling

# %% [markdown]
# ### Train test split

# %%
from sklearn.model_selection import train_test_split

x_train, x_valid, y_train, y_valid = train_test_split(x, y, test_size=0.33, random_state=142, shuffle=True, stratify=y)

# %% [markdown]
# ### Tuning a model

# %%
import PineBioML.model.supervised.Classification as tuner

# %%
rf = tuner.RandomForest_tuner(target="roc_auc_ovr", kernel_seed=11, valid_seed = 222, optuna_seed = 3333).fit(x_train, y_train)
report_utils.classification_summary(y_valid, rf.predict_proba(x_valid))
# Out:
# optuna seed 3333  |  validation seed 222  |  model seed 11
#     RandomForest start tuning. it will take a while.
#     optuna is better, best trial:  14
#
#
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      0.99      1.00       180
#         LIE_TO_SIT       0.50      0.12      0.20         8
#       LIE_TO_STAND       0.42      0.56      0.48         9
#            SITTING       0.80      0.79      0.79       168
#         SIT_TO_LIE       0.53      0.80      0.64        10
#       SIT_TO_STAND       0.00      0.00      0.00         3
#           STANDING       0.81      0.82      0.81       184
#       STAND_TO_LIE       0.57      0.25      0.35        16
#       STAND_TO_SIT       0.38      0.38      0.38         8
#            WALKING       0.82      0.86      0.84       164
# WALKING_DOWNSTAIRS       0.76      0.71      0.73       139
#   WALKING_UPSTAIRS       0.80      0.86      0.83       155
#
#           accuracy                           0.82      1044
#          macro avg       0.61      0.59      0.59      1044
#       weighted avg       0.81      0.82      0.81      1044

# %%
svm = tuner.SVM_tuner(target="qwk", kernel_seed=11, valid_seed = 222, optuna_seed = 3333).fit(x_train, y_train)
report_utils.classification_summary(y_valid, svm.predict_proba(x_valid))
# Out:
# optuna seed 3333  |  validation seed 222  |  model seed 11
#     rbf-SVM start tuning. it will take a while.
#     optuna is better, best trial:  13
#
#
#                     precision    recall  f1-score   support
#
#             LAYING       0.99      1.00      1.00       180
#         LIE_TO_SIT       0.00      0.00      0.00         8
#       LIE_TO_STAND       0.38      0.56      0.45         9
#            SITTING       0.85      0.77      0.81       168
#         SIT_TO_LIE       0.50      0.60      0.55        10
#       SIT_TO_STAND       0.50      0.33      0.40         3
#           STANDING       0.81      0.88      0.84       184
#       STAND_TO_LIE       0.50      0.31      0.38        16
#       STAND_TO_SIT       0.33      0.12      0.18         8
#            WALKING       0.84      0.93      0.88       164
# WALKING_DOWNSTAIRS       0.77      0.71      0.74       139
#   WALKING_UPSTAIRS       0.82      0.83      0.82       155
#
#           accuracy                           0.83      1044
#          macro avg       0.61      0.59      0.59      1044
#       weighted avg       0.83      0.83      0.83      1044

# %%
xgb = tuner.XGBoost_tuner(target="mcc", kernel_seed=11, valid_seed = 222, optuna_seed = 3333).fit(x_train, y_train)
report_utils.classification_summary(y_valid, xgb.predict_proba(x_valid))
# Out:
# optuna seed 3333  |  validation seed 222  |  model seed 11
#     XGBoost start tuning. it will take a while.
#     optuna is better, best trial:  73
#
#
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      0.99      1.00       180
#         LIE_TO_SIT       0.25      0.12      0.17         8
#       LIE_TO_STAND       0.36      0.44      0.40         9
#            SITTING       0.84      0.83      0.83       168
#         SIT_TO_LIE       0.47      0.90      0.62        10
#       SIT_TO_STAND       0.50      0.33      0.40         3
#           STANDING       0.84      0.85      0.85       184
#       STAND_TO_LIE       0.56      0.31      0.40        16
#       STAND_TO_SIT       0.25      0.12      0.17         8
#            WALKING       0.94      0.90      0.92       164
# WALKING_DOWNSTAIRS       0.80      0.80      0.80       139
#   WALKING_UPSTAIRS       0.83      0.90      0.86       155
#
#           accuracy                           0.86      1044
#          macro avg       0.64      0.63      0.62      1044
#       weighted avg       0.86      0.86      0.85      1044

# %%
lgbm = tuner.LighGBM_tuner(target="balanced_accuracy", kernel_seed=11, valid_seed = 222, optuna_seed = 3333).fit(x_train, y_train)
report_utils.classification_summary(y_valid, lgbm.predict_proba(x_valid))
# Out:
# optuna seed 3333  |  validation seed 222  |  model seed 11
#     LightGBM start tuning. it will take a while.
#     optuna is better, best trial:  0
#
#
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      0.99      1.00       180
#         LIE_TO_SIT       0.50      0.25      0.33         8
#       LIE_TO_STAND       0.45      0.56      0.50         9
#            SITTING       0.81      0.80      0.81       168
#         SIT_TO_LIE       0.53      0.80      0.64        10
#       SIT_TO_STAND       0.33      0.33      0.33         3
#           STANDING       0.82      0.83      0.82       184
#       STAND_TO_LIE       0.50      0.38      0.43        16
#       STAND_TO_SIT       0.17      0.12      0.14         8
#            WALKING       0.95      0.90      0.92       164
# WALKING_DOWNSTAIRS       0.80      0.80      0.80       139
#   WALKING_UPSTAIRS       0.82      0.90      0.86       155
#
#           accuracy                           0.85      1044
#          macro avg       0.64      0.64      0.63      1044
#       weighted avg       0.85      0.85      0.85      1044

# %%
elasticnet = tuner.ElasticLogit_tuner(target = "log_loss", kernel_seed=11, valid_seed = 222, optuna_seed = 3333).fit(x_train, y_train)
report_utils.classification_summary(y_valid, elasticnet.predict_proba(x_valid))
# Out:
# optuna seed 3333  |  validation seed 222  |  model seed 11
#     ElasticNetLogisticRegression start tuning. it will take a while.
#     optuna is better, best trial:  8
#
#
#                     precision    recall  f1-score   support
#
#             LAYING       1.00      1.00      1.00       180
#         LIE_TO_SIT       0.60      0.75      0.67         8
#       LIE_TO_STAND       0.40      0.22      0.29         9
#            SITTING       0.69      0.70      0.69       168
#         SIT_TO_LIE       0.40      0.60      0.48        10
#       SIT_TO_STAND       0.67      0.67      0.67         3
#           STANDING       0.73      0.71      0.72       184
#       STAND_TO_LIE       0.36      0.25      0.30        16
#       STAND_TO_SIT       0.36      0.62      0.45         8
#            WALKING       0.78      0.76      0.77       164
# WALKING_DOWNSTAIRS       0.69      0.71      0.70       139
#   WALKING_UPSTAIRS       0.79      0.79      0.79       155
#
#           accuracy                           0.76      1044
#          macro avg       0.62      0.65      0.63      1044
#       weighted avg       0.76      0.76      0.76      1044

# %% [markdown]
# # Output

# %%
# Save the result ro output_path
important_feature.to_csv(output_folder + export_title + " important feature.csv")
importance.to_csv(output_folder+export_title+ " importance.csv")

# %%
from PineBioML.IO import save_model
# save model
save_model(svm, save_path=output_folder+"models/", save_name=export_title+"SVM", overide=True)

# %% [markdown]
# # Reload model

# %%
from PineBioML.IO import load_model
# load model
presaved_model = load_model(output_folder+"models/", export_title+"SVM")

report_utils.classification_summary(y_valid, presaved_model.predict_proba(x_valid))
# Out:
#
#                     precision    recall  f1-score   support
#
#             LAYING       0.99      1.00      1.00       180
#         LIE_TO_SIT       0.00      0.00      0.00         8
#       LIE_TO_STAND       0.38      0.56      0.45         9
#            SITTING       0.85      0.77      0.81       168
#         SIT_TO_LIE       0.50      0.60      0.55        10
#       SIT_TO_STAND       0.50      0.33      0.40         3
#           STANDING       0.81      0.88      0.84       184
#       STAND_TO_LIE       0.50      0.31      0.38        16
#       STAND_TO_SIT       0.33      0.12      0.18         8
#            WALKING       0.84      0.93      0.88       164
# WALKING_DOWNSTAIRS       0.77      0.71      0.74       139
#   WALKING_UPSTAIRS       0.82      0.83      0.82       155
#
#           accuracy                           0.83      1044
#          macro avg       0.61      0.59      0.59      1044
#       weighted avg       0.83      0.83      0.83      1044
